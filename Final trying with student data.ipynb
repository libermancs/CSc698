# %%
import pandas as pd

# %%
from keras.datasets import imdb
# Out:
# Using TensorFlow backend.

# %%
reviews = pd.read_csv('employee_reviews.csv')

# %%
reviews["prosandcons"]=reviews["pros"]+". "+reviews["cons"]

# %%
#Use data that can show you a good results Print out 
#the data after each data to 
#see the current results

# %%
def getsentiment(rating):
    if int(rating) > 3:
        return 1
    if int(rating) <= 3:
        return 0

# %%
reviews["sentiment"]=reviews["overall-ratings"].apply(getsentiment)

# %%
reviews
# Out:
#        Unnamed: 0    company           location          dates  \
# 0               1     google               none   Dec 11, 2018
# 1               2     google  Mountain View, CA   Jun 21, 2013
# 2               3     google       New York, NY   May 10, 2014
# 3               4     google  Mountain View, CA    Feb 8, 2015
# 4               5     google    Los Angeles, CA   Jul 19, 2018
# 5               6     google  Mountain View, CA    Dec 9, 2018
# 6               7     google       New York, NY   Dec 11, 2018
# 7               8     google               none   Dec 11, 2018
# 8               9     google       New York, NY   Dec 10, 2018
# 9              10     google               none    Dec 9, 2018
# 10             11     google  Mountain View, CA    Dec 8, 2018
# 11             12     google               none    Dec 8, 2018
# 12             13     google               none    Dec 4, 2018
# 13             14     google  San Francisco, CA    Dec 3, 2018
# 14             15     google               none    Dec 6, 2018
# 15             16     google               none    Dec 6, 2018
# 16             17     google               none   Nov 29, 2018
# 17             18     google               none    Dec 2, 2018
# 18             19     google               none    Dec 1, 2018
# 19             20     google               none    Dec 3, 2018
# 20             21     google       New York, NY   Nov 26, 2018
# 21             22     google               none    Dec 2, 2018
# 22             23     google               none    Dec 1, 2018
# 23             24     google               none   Nov 30, 2018
# 24             25     google    Los Angeles, CA   Nov 29, 2018
# 25             26     google               none   Nov 29, 2018
# 26             27     google               none   Nov 28, 2018
# 27             28     google  San Francisco, CA   Nov 17, 2018
# 28             29     google               none   Nov 27, 2018
# 29             30     google               none   Nov 20, 2018
# ...           ...        ...                ...            ...
# 67499       67500  microsoft               none   Jan 13, 2011
# 67500       67501  microsoft               none   Jan 11, 2011
# 67501       67502  microsoft  Hyderabad (India)   Dec 26, 2010
# 67502       67503  microsoft               none    Jan 9, 2011
# 67503       67504  microsoft               none    Jan 7, 2011
# 67504       67505  microsoft  Hyderabad (India)    Jan 6, 2011
# 67505       67506  microsoft               none    Jan 6, 2011
# 67506       67507  microsoft               none    Jan 4, 2011
# 67507       67508  microsoft  Hyderabad (India)    Jan 3, 2011
# 67508       67509  microsoft               none    Jan 4, 2011
# 67509       67510  microsoft               none    Jan 4, 2011
# 67510       67511  microsoft  Hyderabad (India)    Jan 4, 2011
# 67511       67512  microsoft  Bengaluru (India)    Jan 1, 2011
# 67512       67513  microsoft               none    Jan 2, 2011
# 67513       67514  microsoft      Tokyo (Japan)    Jan 2, 2011
# 67514       67515  microsoft               none    Jan 3, 2011
# 67515       67516  microsoft               none   Dec 29, 2010
# 67516       67517  microsoft               none   Dec 31, 2010
# 67517       67518  microsoft               none   Dec 30, 2010
# 67518       67519  microsoft               none   Dec 29, 2010
# 67519       67520  microsoft  Hyderabad (India)   Dec 13, 2010
# 67520       67521  microsoft               none   Dec 20, 2010
# 67521       67522  microsoft               none   Dec 22, 2010
# 67522       67523  microsoft               none   Dec 18, 2010
# 67523       67524  microsoft               none   Dec 17, 2010
# 67524       67525  microsoft               none   Dec 16, 2010
# 67525       67526  microsoft               none   Dec 16, 2010
# 67526       67527  microsoft               none   Dec 15, 2010
# 67527       67528  microsoft               none   Dec 15, 2010
# 67528       67529  microsoft               none   Dec 14, 2010
#
#                                                job-title  \
# 0                  Current Employee - Anonymous Employee
# 1                      Former Employee - Program Manager
# 2               Current Employee - Software Engineer III
# 3                  Current Employee - Anonymous Employee
# 4                    Former Employee - Software Engineer
# 5                                 Former Employee - SDE2
# 6                   Current Employee - Software Engineer
# 7                   Former Employee - Anonymous Employee
# 8                  Current Employee - Anonymous Employee
# 9                  Current Employee - Anonymous Employee
# 10                 Current Employee - Anonymous Employee
# 11                 Current Employee - Anonymous Employee
# 12                  Former Employee - Anonymous Employee
# 13           Current Employee - Sales Operations Analyst
# 14                 Current Employee - Anonymous Employee
# 15                 Current Employee - Anonymous Employee
# 16                 Current Employee - Anonymous Employee
# 17                  Former Employee - Anonymous Employee
# 18                  Former Employee - Anonymous Employee
# 19                 Current Employee - Anonymous Employee
# 20                           Current Employee - Designer
# 21                 Current Employee - Anonymous Employee
# 22                 Current Employee - Anonymous Employee
# 23                 Current Employee - Anonymous Employee
# 24                   Current Employee - Staff Accountant
# 25                 Current Employee - Anonymous Employee
# 26                 Current Employee - Anonymous Employee
# 27                  Current Employee - Program Manager I
# 28                 Current Employee - Anonymous Employee
# 29                  Former Employee - Anonymous Employee
# ...                                                  ...
# 67499                 Current Employee - Program Manager
# 67500                       Current Employee - Architect
# 67501               Former Employee - Operations Analyst
# 67502              Current Employee - Anonymous Employee
# 67503              Current Employee - Anonymous Employee
# 67504              Current Employee - Anonymous Employee
# 67505              Current Employee - Anonymous Employee
# 67506                Former Employee - Account Executive
# 67507      Current Employee - Technical Support Engineer
# 67508             Former Employee - Technical Specialist
# 67509             Former Employee - Technical Specialist
# 67510  Current Employee - Software Development Engine...
# 67511     Current Employee - Support Escalation Engineer
# 67512               Former Employee - Anonymous Employee
# 67513             Former Employee - Marketing Specialist
# 67514              Current Employee - Anonymous Employee
# 67515              Current Employee - Operations Manager
# 67516  Current Employee - Software Development Engine...
# 67517              Current Employee - Anonymous Employee
# 67518               Former Employee - Anonymous Employee
# 67519              Current Employee - Anonymous Employee
# 67520              Current Employee - Anonymous Employee
# 67521           Former Employee - Senior Project Managet
# 67522         Current Employee - Technical Sales Manager
# 67523           Former Employee - Senior Program Manager
# 67524               Former Employee - Anonymous Employee
# 67525        Current Employee - Senior Marketing Manager
# 67526                 Current Employee - Account Manager
# 67527                Current Employee - Senior Test Lead
# 67528                  Former Employee - Senior Director
#
#                                                  summary  \
# 0                               Best Company to work for
# 1      Moving at the speed of light, burn out is inev...
# 2      Great balance between big-company security and...
# 3      The best place I've worked and also the most d...
# 4                        Unique, one of a kind dream job
# 5                    NICE working in GOOGLE as an INTERN
# 6                                      Software engineer
# 7                       great place to work and progress
# 8                Google Surpasses Realistic Expectations
# 9                               Execellent for engineers
# 10                                    Nice place to work
# 11                                     Software Engineer
# 12                             Best Company to Work For!
# 13                         Still the best place to work!
# 14                                            Mba Intern
# 15                                                Review
# 16                                      Review of Google
# 17                                              Analysts
# 18                      Great Company With No Down Sides
# 19                                Senior Account Manager
# 20                 Great, but great can always be better
# 21                             Great company to work for
# 22                                                   NaN
# 23                                     Software Engineer
# 24                                            Accountant
# 25                              Good Company to Work for
# 26                                         Great culture
# 27     Not perfect, but still the best place in the w...
# 28                                   Great place to work
# 29                                                 Great
# ...                                                  ...
# 67499                                    Good experience
# 67500  Started kind of shaky, but things are getting ...
# 67501  I would definitely join the company if I grab ...
# 67502                              Good software company
# 67503                     was once a great place to work
# 67504                      Great experience and exposure
# 67505               Great experience - but much pressure
# 67506  It was always difficult, whether it was a mult...
# 67507                                      Great company
# 67508                                Interesting.... :-)
# 67509                                Interesting.... :-)
# 67510  Work life balance is great, Compensation is no...
# 67511                                               GTSC
# 67512         Overall good, however, it depends on group
# 67513                                   Good career path
# 67514  A stable company but still is not for lazy people
# 67515  A: Who do you work for? Me: Microsoft A: I gue...
# 67516                       Mixed - depends on the group
# 67517  if you can work 10-12 hours everyday on regula...
# 67518    Not the cult it used to be - far more a job now
# 67519                            Having fun at Microsoft
# 67520                              a good learning place
# 67521                         Microsoft Services is bad.
# 67522  I started off great some years ago but lately ...
# 67523                                      Good company.
# 67524  Enriching experience for a beginner but bad fo...
# 67525               A complex and interesting experience
# 67526                                 Good Place to Work
# 67527  It's a competitive work place, with overload w...
# 67528                                   Used to be great
#
#                                                     pros  \
# 0                          People are smart and friendly
# 1      1) Food, food, food. 15+ cafes on main campus ...
# 2      * If you're a software engineer, you're among ...
# 3      You can't find a more well-regarded company th...
# 4      Google is a world of its own. At every other c...
# 5      People are not that busy, so they are nice to ...
# 6      Great working environment. Good work life balance
# 7                work culture, benefits, growth, people,
# 8      Great products. Vision you can feel good about...
# 9                 Impact driven. Best tech in the world.
# 10     * Smart people * World class infrastructure * ...
# 11     * There is endless opportunity * You'll never ...
# 12     Atmosphere that promotes the expression of fre...
# 13        Amazing company. Still the best place to work.
# 14          Perks, autonomy, cool products, smart people
# 15                     The people are great to work with
# 16        The people are great to work with, good perks.
# 17     Good managers, benefits , some support, nice a...
# 18              Really fun work environment with startup
# 19     Great benefits, growth and people to work with...
# 20                Great team and support for individuals
# 21                                   I love Google a lot
# 22                           it's a great place to work!
# 23                    Awesome job environment to work in
# 24      I like and learned from the beginning accounting
# 25          - perks are phenomenal, food, health, office
# 26                Very inspiring engineers to work with.
# 27     - A company culture that encourages dissent, d...
# 28     The people are awesome. Lots of perks. Reduce ...
# 29     Great place to work, free food, and great cult...
# ...                                                  ...
# 67499                       Passion for work and company
# 67500  Great benefits. no other place can compare. As...
# 67501  One word - technologies. We are rapidly grabbi...
# 67502  Challenge, professional career growth, high st...
# 67503                    still some pockets of good ppl.
# 67504  An employee's choice of company, great HR prac...
# 67505  One of the best places to work - profesionally...
# 67506  There are some really smart folks working ther...
# 67507  1. Good salary 2. Good benefits 3. Overall ver...
# 67508  Knowledge Sharing Dynamic Teams Great career "...
# 67509  Knowledge Sharing Dynamic Teams Great career "...
# 67510  Best company for entry level Engineer. Good Wo...
# 67511  highly technical and motivated people one can ...
# 67512  Has great benefit package. Most of the time yo...
# 67513  You can learn and experience lots of things at...
# 67514     - Good benefit so far - Large, lots of variety
# 67515  - good benefits and perks, free Windows Phone ...
# 67516  I had one group that was pretty good with orga...
# 67517  Some really smart people to work with. If you ...
# 67518                     lots of new stuff almost daily
# 67519  Unlimited opportunities, fun, great networking...
# 67520  It is a big company. So if you really want to ...
# 67521  MS is a good company but hire wrong people. Wo...
# 67522  Employee empowerment Ability to take your init...
# 67523         Good benefits package, huge customer base.
# 67524  -Access to a wide range of technologies, compl...
# 67525  - Once you're at Microsoft you can change role...
# 67526  Nice place to work. Good atmosphere with advan...
# 67527       Smart people around you, can learn from them
# 67528  Compensation, Health benefits and brand name r...
#
#                                                     cons  \
# 0                     Bureaucracy is slowing things down
# 1      1) Work/life balance. What balance? All those ...
# 2      * It *is* becoming larger, and with it comes g...
# 3      I live in SF so the commute can take between 1...
# 4      If you don't work in MTV (HQ), you will be giv...
# 5      Food is not good as I expected. People said it...
# 6                 Usual big company problems. Hierarchy.
# 7                            No cons that i can think of
# 8      Younger employees complaining about the compan...
# 9      Size matters. Engineers are a bit disconnected...
# 10     Giant company with uneven project and team cha...
# 11     * There's always someone better than you. * Yo...
# 12     It can be an overwhelming machine at times but...
# 13     Size, which limits opportunities for extraordi...
# 14                  Slow career progression for non-tech
# 15             There is lower compensation than expected
# 16             Wide variety in experience based on team.
# 17              Long hours, far locations, a lot of work
# 18                      Really no down sides that I saw.
# 19                          Must be located in an office
# 20                Lots of bureaucracy, not super diverse
# 21                          Some things are not to great
# 22     too much red tape on doing even the smallest p...
# 23                      Pressure is there for some parts
# 24                 High clerical work in the Sane record
# 25                 - work life balance is hard to manage
# 26        Easy to get lost, as it is such a big company.
# 27     - A company with over 90k people at the time o...
# 28     There's sometimes too wide a variety of things...
# 29     Big company, prepare to move much slower than ...
# ...                                                  ...
# 67499  Lot of opportunities. Unable to juggle for per...
# 67500  Sometimes it feels too big! too many organizat...
# 67501  It takes times to find your way but once you d...
# 67502         Keen competition. Hard working, stressful.
# 67503  was great now filled w/ lots of ppl who outsou...
# 67504  depending on division, career advancement may ...
# 67505  very pressing and therefore not enough time fo...
# 67506  Meetings, meetings and more meetings. Secret a...
# 67507  It varies from team to team - If you ar estuck...
# 67508  - Grew too fast - Windows & , Windows & Office...
# 67509  - Grew too fast - Windows & , Windows & Office...
# 67510  If you joined on a wrong level, No matter how ...
# 67511  Hire on perception known devil is better than ...
# 67512  Takes long time to make a decision. Difficult ...
# 67513  Difficult to work with some senior management ...
# 67514              - Need to follow many rules/processes
# 67515  - your life quality, promotions, recognitions ...
# 67516  Another group was terrible - there was no coor...
# 67517  For working mothers, hard place to grow and ke...
# 67518       processes are killing it and losing momentum
# 67519  Long hours (but then most companies today requ...
# 67520  Like any other big companies, it is sometimes ...
# 67521  Senior management has no leadership and very o...
# 67522  Company too slow Bureaucratic Lacking consumer...
# 67523            Politics, very slow, lots of dead wood.
# 67524  -Testers(SDET's ) do not get as many opportuni...
# 67525  - Be prepared to be flexible - frequent change...
# 67526  Management confusion at times with vision for ...
# 67527              Politics, weak moral, leaning loyalty
# 67528  Leadership was better in the late 90's....its ...
#
#                                           advice-to-mgmt  overall-ratings  \
# 0                                                   none              5.0
# 1      1) Don't dismiss emotional intelligence and ad...              4.0
# 2      Keep the focus on the user. Everything else wi...              5.0
# 3      Keep on NOT micromanaging - that is a huge ben...              5.0
# 4      Promote managers into management for their man...              5.0
# 5                                                   none              5.0
# 6                                                   none              5.0
# 7                                                   none              5.0
# 8                                                   none              5.0
# 9                                                   none              5.0
# 10                                                  none              5.0
# 11                                                  none              5.0
# 12                                                  none              5.0
# 13                                                  none              5.0
# 14                                                  none              5.0
# 15                                                  none              5.0
# 16                                                  none              5.0
# 17                                                  none              5.0
# 18                                                  none              5.0
# 19                                                  none              5.0
# 20                                                  none              5.0
# 21                                                  none              5.0
# 22                                                  none              5.0
# 23                                                  none              5.0
# 24     Management and Finance must be close relation ...              5.0
# 25                                                  none              5.0
# 26                                                  none              5.0
# 27     - Just because a small percentage of the compa...              5.0
# 28                                                  none              5.0
# 29                                                  none              5.0
# ...                                                  ...              ...
# 67499          Not much. Management doesn't need advice.              4.0
# 67500  Be fair when it comes to treating with all you...              3.0
# 67501  Every manager is unique. Unless you really kno...              5.0
# 67502                                               none              4.0
# 67503          change out CEO, change approach to review              2.0
# 67504                                               none              4.0
# 67505  Management is very professional but it would b...              4.0
# 67506  Do away with annual reviews. Make your manager...              2.0
# 67507  Nothing much - just keep doing whatever you ar...              3.0
# 67508  - Direct & Manage the talent, not confuse with...              4.0
# 67509  - Direct & Manage the talent, not confuse with...              4.0
# 67510            Promotions need to be more transparent,              3.0
# 67511      respect the skill set and not the perceptions              3.0
# 67512                                               none              4.0
# 67513                                               none              3.0
# 67514                        Hold their MS stocks longer              4.0
# 67515  you have more people in the team, not only the...              3.0
# 67516  Try for greater consistency between the teams....              3.0
# 67517                                               none              3.0
# 67518                                               none              3.0
# 67519                                               none              5.0
# 67520                                               none              4.0
# 67521  Major management revamp esp in APAC. It's not ...              2.0
# 67522                                               none              3.0
# 67523                                           Move on.              4.0
# 67524  Make the company leaner and Meaner. (which wou...              3.0
# 67525                                               none              3.0
# 67526                                               none              4.0
# 67527                                               none              3.0
# 67528  Good people keep leaving...you have to ask you...              2.0
#
#       work-balance-stars culture-values-stars carrer-opportunities-stars  \
# 0                    4.0                  5.0                        5.0
# 1                    2.0                  3.0                        3.0
# 2                    5.0                  4.0                        5.0
# 3                    2.0                  5.0                        5.0
# 4                    5.0                  5.0                        5.0
# 5                    4.0                  4.0                        4.0
# 6                    5.0                  4.0                        4.0
# 7                    5.0                  5.0                        5.0
# 8                    5.0                  5.0                        5.0
# 9                    5.0                  5.0                        5.0
# 5      People are not that busy, so they are nice to ...          1
# 6      Great working environment. Good work life bala...          1
# 7      work culture, benefits, growth, people,. No co...          1
# 8      Great products. Vision you can feel good about...          1
# 9      Impact driven. Best tech in the world.. Size m...          1
# 10     * Smart people * World class infrastructure * ...          1
# 11     * There is endless opportunity * You'll never ...          1
# 12     Atmosphere that promotes the expression of fre...          1
# 13     Amazing company. Still the best place to work....          1
# 14     Perks, autonomy, cool products, smart people. ...          1
# 15     The people are great to work with. There is lo...          1
# 16     The people are great to work with, good perks....          1
# 17     Good managers, benefits , some support, nice a...          1
# 18     Really fun work environment with startup. Real...          1
# 19     Great benefits, growth and people to work with...          1
# 20     Great team and support for individuals. Lots o...          1
# 21     I love Google a lot. Some things are not to great          1
# 22     it's a great place to work!. too much red tape...          1
# 23     Awesome job environment to work in. Pressure i...          1
# 24     I like and learned from the beginning accounti...          1
# 25     - perks are phenomenal, food, health, office. ...          1
# 26     Very inspiring engineers to work with.. Easy t...          1
# 27     - A company culture that encourages dissent, d...          1
# 28     The people are awesome. Lots of perks. Reduce ...          1
# 29     Great place to work, free food, and great cult...          1
# ...                                                  ...        ...
# 67499  Passion for work and company. Lot of opportuni...          1
# 67500  Great benefits. no other place can compare. As...          0
# 67501  One word - technologies. We are rapidly grabbi...          1
# 67502  Challenge, professional career growth, high st...          1
# 67503  still some pockets of good ppl.. was great now...          0
# 67504  An employee's choice of company, great HR prac...          1
# 67505  One of the best places to work - profesionally...          1
# 67506  There are some really smart folks working ther...          0
# 67507  1. Good salary 2. Good benefits 3. Overall ver...          0
# 67508  Knowledge Sharing Dynamic Teams Great career "...          1
# 67509  Knowledge Sharing Dynamic Teams Great career "...          1
# 67510  Best company for entry level Engineer. Good Wo...          0
# 67511  highly technical and motivated people one can ...          0
# 67512  Has great benefit package. Most of the time yo...          1
# 67513  You can learn and experience lots of things at...          0
# 67514  - Good benefit so far - Large, lots of variety...          1
# 67515  - good benefits and perks, free Windows Phone ...          0
# 67516  I had one group that was pretty good with orga...          0
# 67517  Some really smart people to work with. If you ...          0
# 67518  lots of new stuff almost daily. processes are ...          0
# 67519  Unlimited opportunities, fun, great networking...          1
# 67520  It is a big company. So if you really want to ...          1
# 67521  MS is a good company but hire wrong people. Wo...          0
# 67522  Employee empowerment Ability to take your init...          0
# 67523  Good benefits package, huge customer base.. Po...          1
# 67524  -Access to a wide range of technologies, compl...          0
# 67525  - Once you're at Microsoft you can change role...          0
# 67526  Nice place to work. Good atmosphere with advan...          1
# 67527  Smart people around you, can learn from them. ...          0
# 67528  Compensation, Health benefits and brand name r...          0
#
# [67529 rows x 19 columns]

# %%
data = reviews[['prosandcons','sentiment']]

# %%
s_reviews = pd.read_csv('Use.csv')

# %%
s_reviews["sentiment"]=s_reviews["score"].apply(getsentiment)

# %%
s_reviews
# Out:
#          Timestamp  score                                            reviews  \
# 0    2/15/19 13:42      1  we suck.                                      ...
# 1    2/15/19 14:37      1  no naptime / cheese ohnononononnononononononon...
# 2    2/15/19 11:06      2  Because of mr liberman and i need to calm down...
# 3    2/15/19 11:08      2  I gave this class a 2 because it is too fast f...
# 4    2/15/19 11:06      3  Mr. Liberman is a fun teacher but we have to r...
# 5    2/15/19 11:06      3  I like this class because my friend is in this...
# 6    2/15/19 11:07      3  It's fun and everything but we watch too many ...
# 7    2/15/19 11:07      3  It's kind of boring and has not  been any  pro...
# 8    2/15/19 11:09      3  TO MU WRITINGGGG---------\n\n\n\n\n-----pppppp...
# 9    2/15/19 11:10      3  i gave this score because this class is helpfu...
# 10   2/15/19 11:56      3  I have no opinion, the class was fine! To make...
# 11   2/15/19 13:07      3  We donÂ´t really listen. We donÂ´t stay on tra...
# 12   2/15/19 13:40      3  Maybe we should do less writing and more video...
# 13   2/15/19 13:40      3  It is good but we have to write a lot of notes...
# 14   2/15/19 14:38      3  Some people talk a lot and we are very loud, b...
# 15   2/15/19 15:30      3  I like that Mr. Liberman doesn't yell at us th...
# 16   2/15/19 15:31      3  i dont know cause peoples talk and some people...
# 17   2/15/19 11:06      4  4.5 because everything is good except the essa...
# 18   2/15/19 11:07      4  I rate this class a four because we have to ta...
# 19   2/15/19 11:07      4  it's a good class but you need to give us less...
# 20   2/15/19 11:07      4  mr liberman is a really good teacher and lets ...
# 21   2/15/19 11:07      4  Sometimes mr.liberman can get a better timer a...
# 22   2/15/19 11:07      4  The class is good we don't really talk that mu...
# 23   2/15/19 11:07      4  I give the class that score because I like the...
# 24   2/15/19 11:08      4  The class is a good class, everyone is respect...
# 25   2/15/19 11:08      4  people shout often but other than that it is g...
# 26   2/15/19 11:09      4  Idk. (I need to write more so imma just type r...
# 27   2/15/19 11:09      4  This class is good because everyone works well...
# 28   2/15/19 11:10      4  Something good about our class is that it is f...
# 29   2/15/19 11:57      4  I think it's a good class because we learn thi...
# ..             ...    ...                                                ...
# 152            NaN      3  It can be more quiet and i can focus more and ...
# 153            NaN      3  i gave it that score because i think the class...
# 154            NaN      3  because i dont do it and i will try to finish ...
# 155            NaN      3  I don't think I did good i think I did OK, but...
# 156            NaN      3  The good is they get quiet the bad thing is th...
# 157            NaN      3  something that is good about this class is tha...
# 158            NaN      2  2 because it's boring.SFSFSFSFSFSFSFSFSFSFSFSF...
# 159            NaN      3  In the middle because we always talk every tim...
# 160            NaN      2  2 because it's boring. SFSFSFSFSFSFSFSFSFSFSFS...
# 161            NaN      3  Its a 3 because the class gets annoying and bo...
# 162            NaN      2  nothing because this class is orng becaus e we...
# 163            NaN      3  they are okay and nothing is wrong and they co...
# 164            NaN      4  I gave the class this grade because they are p...
# 165            NaN      4  idk be i dont rlly care tbh but yea just say s...
# 166            NaN      2  the class needs to focus on their work. turn i...
# 167            NaN      3  This class can be fun and I learn I a lot don'...
# 168            NaN      3  its a good class and things get done but some ...
# 169            NaN      4  oneÊ thingÊ goodÊ aboutÊ thisÊ classÊ isÊ some...
# 170            NaN      3  It's not bad or good, it's like every other cl...
# 171            NaN      2  That you stop yelling at us an be a better tea...
# 172            NaN      2  It is 2 because because i need to catch up on ...
# 173            NaN      3  in feel like it is a okay score think the mini...
# 179                  NaN                   NaN          NaN         NaN
# 180                  NaN                   NaN          NaN         NaN
# 181                  NaN                   NaN          NaN         NaN
#
#      Flag Data  sentiment
# 0          NaN          0
# 1          NaN          0
# 2          NaN          0
# 3          NaN          0
# 4          NaN          0
# 5          NaN          0
# 6          NaN          0
# 7          NaN          0
# 8          NaN          0
# 9          NaN          0
# 10         NaN          0
# 11         NaN          0
# 12         NaN          0
# 13         NaN          0
# 14         NaN          0
# 15         NaN          0
# 16         NaN          0
# 17         NaN          1
# 18         NaN          1
# 19         NaN          1
# 20         NaN          1
# 21         NaN          1
# 22         NaN          1
# 23         NaN          1
# 24         NaN          1
# 25         NaN          1
# 26         NaN          1
# 27         NaN          1
# 28         NaN          1
# 29         NaN          1
# ..         ...        ...
# 152        NaN          0
# 153        NaN          0
# 154        NaN          0
# 155        NaN          0
# 156        NaN          0
# 157        NaN          0
# 158        NaN          0
# 159        NaN          0
# 160        NaN          0
# 161        NaN          0
# 162        NaN          0
# 163        NaN          0
# 164        NaN          1
# 165        NaN          1
# 166        NaN          0
# 167        NaN          0
# 168        NaN          0
# 169        NaN          1
# 170        NaN          0
# 171        NaN          0
# 172        NaN          0
# 173        NaN          0
# 174        NaN          1
# 175        NaN          0
# 176        NaN          0
# 177        NaN          1
# 178        NaN          0
# 179        NaN          0
# 180        NaN          0
# 181        NaN          0
#
# [182 rows x 9 columns]

# %%
data
# Out:
#                                              prosandcons  sentiment
# 0      People are smart and friendly. Bureaucracy is ...          1
# 1      1) Food, food, food. 15+ cafes on main campus ...          1
# 2      * If you're a software engineer, you're among ...          1
# 3      You can't find a more well-regarded company th...          1
# 4      Google is a world of its own. At every other c...          1
# 5      People are not that busy, so they are nice to ...          1
# 6      Great working environment. Good work life bala...          1
# 7      work culture, benefits, growth, people,. No co...          1
# 8      Great products. Vision you can feel good about...          1
# 9      Impact driven. Best tech in the world.. Size m...          1
# 10     * Smart people * World class infrastructure * ...          1
# 11     * There is endless opportunity * You'll never ...          1
# 12     Atmosphere that promotes the expression of fre...          1
# 13     Amazing company. Still the best place to work....          1
# 14     Perks, autonomy, cool products, smart people. ...          1
# 15     The people are great to work with. There is lo...          1
# 16     The people are great to work with, good perks....          1
# 17     Good managers, benefits , some support, nice a...          1
# 18     Really fun work environment with startup. Real...          1
# 19     Great benefits, growth and people to work with...          1
# 20     Great team and support for individuals. Lots o...          1
# 21     I love Google a lot. Some things are not to great          1
# 22     it's a great place to work!. too much red tape...          1
# 23     Awesome job environment to work in. Pressure i...          1
# 24     I like and learned from the beginning accounti...          1
# 25     - perks are phenomenal, food, health, office. ...          1
# 26     Very inspiring engineers to work with.. Easy t...          1
# 27     - A company culture that encourages dissent, d...          1
# 28     The people are awesome. Lots of perks. Reduce ...          1
# 29     Great place to work, free food, and great cult...          1
# ...                                                  ...        ...
# 67499  Passion for work and company. Lot of opportuni...          1
# 67500  Great benefits. no other place can compare. As...          0
# 67501  One word - technologies. We are rapidly grabbi...          1
# 67502  Challenge, professional career growth, high st...          1
# 67503  still some pockets of good ppl.. was great now...          0
# 67504  An employee's choice of company, great HR prac...          1
# 67505  One of the best places to work - profesionally...          1
# 67506  There are some really smart folks working ther...          0
# 67507  1. Good salary 2. Good benefits 3. Overall ver...          0
# 67508  Knowledge Sharing Dynamic Teams Great career "...          1
# 67509  Knowledge Sharing Dynamic Teams Great career "...          1
# 67510  Best company for entry level Engineer. Good Wo...          0
# 67511  highly technical and motivated people one can ...          0
# 67512  Has great benefit package. Most of the time yo...          1
# 67513  You can learn and experience lots of things at...          0
# 67514  - Good benefit so far - Large, lots of variety...          1
# 67515  - good benefits and perks, free Windows Phone ...          0
# 67516  I had one group that was pretty good with orga...          0
# 67517  Some really smart people to work with. If you ...          0
# 67518  lots of new stuff almost daily. processes are ...          0
# 67519  Unlimited opportunities, fun, great networking...          1
# 67520  It is a big company. So if you really want to ...          1
# 67521  MS is a good company but hire wrong people. Wo...          0
# 67522  Employee empowerment Ability to take your init...          0
# 67523  Good benefits package, huge customer base.. Po...          1
# 67524  -Access to a wide range of technologies, compl...          0
# 67525  - Once you're at Microsoft you can change role...          0
# 67526  Nice place to work. Good atmosphere with advan...          1
# 67527  Smart people around you, can learn from them. ...          0
# 67528  Compensation, Health benefits and brand name r...          0
#
# [67529 rows x 2 columns]

# %%
X =  data['prosandcons']

y = data['sentiment']

# %%
#Student Data
sX =  s_reviews['reviews']

sy = s_reviews['sentiment']

# %%
#Tokenizing Glassdoor
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X) 
sequences = tokenizer.texts_to_sequences(X)


word_index = tokenizer.word_index
print('unique words %s' % len(word_index))

stupiddata = pad_sequences(sequences, maxlen=500, padding='post')
print('data shape:', stupiddata.shape)
# Out:
# unique words 38357
# data shape: (67529, 500)

# %%
#Tokenizing Student Reviews
stokenizer = Tokenizer()
stokenizer.fit_on_texts(sX) 
ssequences = tokenizer.texts_to_sequences(sX)


sword_index = tokenizer.word_index
print('unique words %s' % len(sword_index))

sstupiddata = pad_sequences(ssequences, maxlen=500, padding='post')
print('data shape:', sstupiddata.shape)
# Out:
# unique words 38357
# data shape: (182, 500)

# %%
#Split data Glassdoor
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(stupiddata,y , test_size=0.2, random_state=42)

# %%
#Split data Student
from sklearn.model_selection import train_test_split
sX_train, sX_test, sy_train, sy_test = train_test_split(sstupiddata,sy , test_size=0.2, random_state=42)

# %%
# print('Maximum review length: {}'.format(
# len(max((X_train + X_test), key=len))))

# %%
# print('Minimum review length: {}'.format(
# len(min((X_test + X_test), key=len))))

# %%
# from keras.preprocessing import sequence
# max_words = 500
# X_train = sequence.pad_sequences(X_train, maxlen=max_words)
# X_test = sequence.pad_sequences(X_test, maxlen=max_words)

# %%
#Glove Vectors loaded
import numpy as np

embeddings_index = {}

f = open('glove.6B.100d.txt', encoding="utf8")

for line in f:

    values = line.split()

    word = values[0]

    coefs = np.asarray(values[1:], dtype='float32')

    embeddings_index[word] = coefs

f.close()

 

print('Total %s word vectors.' % len(embeddings_index))
# Out:
# Total 400000 word vectors.

# %%
#do not need to do pipelining

#want to use the model.fit- parse the train data and then specify the epochs and batch size.


# prepare embeddings for layer
from keras.layers.embeddings import Embedding

words_max = len(word_index)+1

embedding_matrix = np.zeros((len(word_index)+1, 100))

for word, i in word_index.items():

    if i >= words_max:

        continue

    embedding_vector = embeddings_index.get(word)

    if embedding_vector is not None:

        embedding_matrix[i] = embedding_vector

# %%
##this is where add Karuna Code
# Create an non re-trainable embedding layer with embedding size 100

nb_words = len(word_index)+1

embedding_layer = Embedding(nb_words,100,

        weights=[embedding_matrix],

        input_length=500,

        trainable=True)

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
embedding_size=32
model=Sequential()
model.add(embedding_layer)
# model.add(Embedding(5000, embedding_size, input_length=500))
model.add(LSTM(100))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 100)          3835800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 3,916,301
# Trainable params: 3,916,301
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])

# %%
batch_size = 75
num_epochs = 17

X_valid, y_valid = X_train[:batch_size], y_train[:batch_size]
X_train2, y_train2 = X_train[batch_size:], y_train[batch_size:]
model.fit(X_train2, y_train2, validation_data=(X_valid, y_valid), batch_size=batch_size, epochs=num_epochs)

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', scores[1])

# %%
#Batch 2 with 2 LSTMS THE WINNING MODEL

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
embedding_size=32
model=Sequential()
model.add(embedding_layer)
# model.add(Embedding(5000, embedding_size, input_length=500))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(32))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 500, 100)          3835800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 500, 100)          80400
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                17024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 3,933,257
# Trainable params: 3,933,257
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model.compile(loss='mean_squared_error', 
             optimizer='adam', 
             metrics=['accuracy'])

# %%
batch_size = 75
num_epochs = 17

X_valid, y_valid = X_train[:batch_size], y_train[:batch_size]
X_train2, y_train2 = X_train[batch_size:], y_train[batch_size:]
model.fit(X_train2, y_train2, validation_data=(X_valid, y_valid), batch_size=batch_size, epochs=num_epochs)
# Out:
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 53948 samples, validate on 75 samples
# Epoch 1/17
# 53948/53948 [==============================] - 1311s 24ms/step - loss: 0.2193 - acc: 0.6784 - val_loss: 0.2031 - val_acc: 0.7200
# Epoch 2/17
# 53948/53948 [==============================] - 1247s 23ms/step - loss: 0.2188 - acc: 0.6779 - val_loss: 0.2011 - val_acc: 0.7200
# Epoch 3/17
# 53948/53948 [==============================] - 1646s 31ms/step - loss: 0.2184 - acc: 0.6792 - val_loss: 0.2022 - val_acc: 0.7333
# Epoch 4/17
# 53948/53948 [==============================] - 1663s 31ms/step - loss: 0.2181 - acc: 0.6798 - val_loss: 0.1978 - val_acc: 0.7333
# Epoch 5/17
# 53948/53948 [==============================] - 1650s 31ms/step - loss: 0.2171 - acc: 0.6799 - val_loss: 0.1911 - val_acc: 0.7333
# Epoch 6/17
# 53948/53948 [==============================] - 1636s 30ms/step - loss: 0.2055 - acc: 0.6928 - val_loss: 0.1997 - val_acc: 0.7333
# Epoch 7/17
# 53948/53948 [==============================] - 1627s 30ms/step - loss: 0.2180 - acc: 0.6802 - val_loss: 0.1987 - val_acc: 0.7333
# Epoch 8/17
# 53948/53948 [==============================] - 1621s 30ms/step - loss: 0.2176 - acc: 0.6804 - val_loss: 0.1976 - val_acc: 0.7333
# Epoch 9/17
# 53948/53948 [==============================] - 1570s 29ms/step - loss: 0.2175 - acc: 0.6806 - val_loss: 0.1975 - val_acc: 0.7333
# Epoch 10/17
# 53948/53948 [==============================] - 1087s 20ms/step - loss: 0.2175 - acc: 0.6807 - val_loss: 0.1987 - val_acc: 0.7333
# Epoch 11/17
# 53948/53948 [==============================] - 1088s 20ms/step - loss: 0.2173 - acc: 0.6809 - val_loss: 0.1957 - val_acc: 0.7333
# Epoch 12/17
# 53948/53948 [==============================] - 1083s 20ms/step - loss: 0.2174 - acc: 0.6809 - val_loss: 0.1971 - val_acc: 0.7333
# Epoch 13/17
# 53948/53948 [==============================] - 1100s 20ms/step - loss: 0.2172 - acc: 0.6809 - val_loss: 0.1967 - val_acc: 0.7333
# Epoch 14/17
# 53948/53948 [==============================] - 1090s 20ms/step - loss: 0.2169 - acc: 0.6808 - val_loss: 0.1952 - val_acc: 0.7333
# Epoch 15/17
# 53948/53948 [==============================] - 1090s 20ms/step - loss: 0.2173 - acc: 0.6808 - val_loss: 0.1973 - val_acc: 0.7333
# Epoch 16/17
# 53948/53948 [==============================] - 1090s 20ms/step - loss: 0.2171 - acc: 0.6809 - val_loss: 0.1977 - val_acc: 0.7333
# Epoch 17/17
# 53948/53948 [==============================] - 1088s 20ms/step - loss: 0.2171 - acc: 0.6810 - val_loss: 0.1971 - val_acc: 0.7333

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.6728120835184362

# %%
#Student Data Test
scores = model.evaluate(sX_test, sy_test, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.7837837837837838

# %%
#The code below was trying to get higher accuracy through changing the model, but the above model ran the best

# %%
#Stacked LSTM MODEL

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
embedding_size=32
model=Sequential()
model.add(embedding_layer)
# model.add(Embedding(5000, embedding_size, input_length=500))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))

model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())

# %%
model.compile(loss='mean_squared_error', 
             optimizer='adam', 
             metrics=['accuracy'])

# %%
batch_size = 75
num_epochs = 34

X_valid, y_valid = X_train[:batch_size], y_train[:batch_size]
X_train2, y_train2 = X_train[batch_size:], y_train[batch_size:]
model.fit(X_train2, y_train2, validation_data=(X_valid, y_valid), batch_size=batch_size, epochs=num_epochs)

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', scores[1])

# %%
#3rd Model with 3 LSTMS More Epochs and Keras Callback early stopping  - did not improve - too early
# Note min delta .1 too early , changed to .6 to see if can improve - did not improve - too early
# Note min delta .6 too early , changed to 5 to see if can improve - Did not improve - too early
# Note min delta .6 too early , changed patience from 2 to 3.5 and kept min delta at .005

# %%
from keras import Sequential, callbacks
from keras.layers import Embedding, LSTM, Dense, Dropout
es = [callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3.5, min_delta=.005)]
embedding_size=32
model=Sequential()
model.add(embedding_layer)
# model.add(Embedding(5000, embedding_size, input_length=500))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))

model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())

# %%
model.compile(loss='mean_squared_error', 
             optimizer='adam', 
             metrics=['accuracy'])

# %%
batch_size = 75
num_epochs = 25

X_valid, y_valid = X_train[:batch_size], y_train[:batch_size]
X_train2, y_train2 = X_train[batch_size:], y_train[batch_size:]
model.fit(X_train2, y_train2, validation_data=(X_valid, y_valid), batch_size=batch_size, epochs=num_epochs, callbacks=es)

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print('Test accuracy:', scores[1])

# %%
#New

# %%
from keras import Sequential, callbacks
from keras.layers import Embedding, LSTM, Dense, Dropout
es = [callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3.2, min_delta=.01)]
embedding_size=32
model=Sequential()
model.add(embedding_layer)
# model.add(Embedding(5000, embedding_size, input_length=500))
model.add(LSTM(100, return_sequences=True))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))

model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))
print(model.summary())

# %%
model.compile(loss='mean_squared_error', 
             optimizer='adam', 
             metrics=['accuracy'])

# %%
batch_size = 75
num_epochs = 25

X_valid, y_valid = X_train[:batch_size], y_train[:batch_size]
X_train2, y_train2 = X_train[batch_size:], y_train[batch_size:]
model.fit(X_train2, y_train2, validation_data=(X_valid, y_valid), batch_size=batch_size, epochs=num_epochs, callbacks=es)

# %% [raw]
# scores = model.evaluate(X_test, y_test, verbose=0)
# print('Test accuracy:', scores[1])
